# %%
import kinetics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Glucose path ODE validation

# %%
# initial condition
Glc_ext = 0.0

# user-defined glucose input
Glc_in = 2.0

dt = 0.01
steps = 500

history = []

for _ in range(steps):
    Glc_ext += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    history.append(Glc_ext)

history = np.array(history)

plt.plot(history, label="Glc_ext")
plt.legend()
plt.show()

# %%
# --- initial conditions ---
Glc_ext = 0.0
Glc     = 5.0

# --- user-defined input ---
Glc_in = 2.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    # update both states
    Glc_ext += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc     += dt * kinetics.dGlc_dt(Glc, Glc_ext)

    history.append([Glc_ext, Glc])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.legend()
plt.show()

print("Final Glc_ext:", history[-1, 0])
print("Final Glc:", history[-1, 1])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.24776559731834236

# %%
# --- initial conditions ---
Glc_ext = 0.0
Glc     = 0.0
Glc6P   = 0.0

# --- user-defined input ---
Glc_in = 2.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    # update states
    Glc_ext += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc     += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P   += dt * kinetics.dGlc6P_dt(Glc6P, Glc)

    history.append([Glc_ext, Glc, Glc6P])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.legend()
plt.show()

# --- final values ---
print("Final Glc_ext:", history[-1, 0])
print("Final Glc:", history[-1, 1])
print("Final Glc6P:", history[-1, 2])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203

# %%
# --- initial conditions ---
Glc_ext = 0.0
Glc     = 0.0
Glc6P   = 0.0
Fru6P   = 0.0

# --- user-defined input ---
Glc_in = 2.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    Glc_ext += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc     += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P   += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P   += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit=0.0)  # no citrate yet

    history.append([Glc_ext, Glc, Glc6P, Fru6P])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.plot(history[:,3], label="Fru6P")
plt.legend()
plt.show()

# --- final values ---
print("Final Glc_ext:", history[-1, 0])
print("Final Glc:", history[-1, 1])
print("Final Glc6P:", history[-1, 2])
print("Final Fru6P:", history[-1, 3])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203
# Final Fru6P: 0.049979178373254655

# %%
# --- initial conditions ---
Glc_ext  = 0.0
Glc      = 0.0
Glc6P    = 0.0
Fru6P    = 0.0
Fru16P2  = 0.0

# --- user-defined input ---
Glc_in = 2.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    Glc_ext  += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc      += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P    += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P    += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit=0.0)
    Fru16P2  += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit=0.0)

    history.append([Glc_ext, Glc, Glc6P, Fru6P, Fru16P2])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.plot(history[:,3], label="Fru6P")
plt.plot(history[:,4], label="Fru16P2")
plt.legend()
plt.show()

# --- final values ---
print("Final Glc_ext:", history[-1, 0])
print("Final Glc:", history[-1, 1])
print("Final Glc6P:", history[-1, 2])
print("Final Fru6P:", history[-1, 3])
print("Final Fru16P2:", history[-1, 4])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203
# Final Fru6P: 0.049979178373254655
# Final Fru16P2: 0.06046981043156509

# %%
# --- initial conditions ---
Glc_ext  = 0.0
Glc      = 0.0
Glc6P    = 0.0
Fru6P    = 0.0
Fru16P2  = 0.0
Pyruvate = 0.0

# --- user-defined input ---
Glc_in = 2.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    Glc_ext  += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc      += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P    += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P    += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit=0.0)
    Fru16P2  += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit=0.0)
    Pyruvate += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc=0.0)

    history.append([Glc_ext, Glc, Glc6P, Fru6P, Fru16P2, Pyruvate])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.plot(history[:,3], label="Fru6P")
plt.plot(history[:,4], label="Fru16P2")
plt.plot(history[:,5], label="Pyruvate")
plt.legend()
plt.show()

# --- final values ---
print("Final Glc_ext:", history[-1, 0])
print("Final Glc:", history[-1, 1])
print("Final Glc6P:", history[-1, 2])
print("Final Fru6P:", history[-1, 3])
print("Final Fru16P2:", history[-1, 4])
print("Final Pyruvate:", history[-1, 5])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203
# Final Fru6P: 0.049979178373254655
# Final Fru16P2: 0.06046981043156509
# Final Pyruvate: 0.07151175876445386

# %%
# --- initial conditions ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- user-defined input ---
Glc_in = 2.0
ATP_draw = 1.0

# --- integration settings ---
dt = 0.01
steps = 500

history = []

for _ in range(steps):
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit=0.0)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit=0.0)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    history.append([Glc_ext, Glc, Glc6P, Fru6P, Fru16P2, Pyruvate, AcCoA_Glc])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.plot(history[:,3], label="Fru6P")
plt.plot(history[:,4], label="Fru16P2")
plt.plot(history[:,5], label="Pyruvate")
plt.plot(history[:,6], label="AcCoA_Glc")
plt.legend()
plt.show()

# --- final values ---
print("Final Glc_ext:",   history[-1, 0])
print("Final Glc:",       history[-1, 1])
print("Final Glc6P:",     history[-1, 2])
print("Final Fru6P:",     history[-1, 3])
print("Final Fru16P2:",   history[-1, 4])
print("Final Pyruvate:",  history[-1, 5])
print("Final AcCoA_Glc:", history[-1, 6])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203
# Final Fru6P: 0.049979178373254655
# Final Fru16P2: 0.06046981043156509
# Final Pyruvate: 0.07739740210573214
# Final AcCoA_Glc: 0.23443998628024895

# %%
# ============================
# INITIAL CONDITIONS
# ============================

Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0
AcCoA_Fat  = 0.0    # <-- added for citrate ODE
Cit        = 0.0


# ============================
# USER INPUTS
# ============================

Glc_in    = 2.0
ATP_draw  = 1.0


# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 500

history = []


# ============================
# MAIN INTEGRATION LOOP
# ============================

for _ in range(steps):

    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # NEW: citrate from both AcCoA pools
    Cit       += dt * kinetics.dCit_dt(Cit, AcCoA_Glc, AcCoA_Fat, Glc)

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc, Cit
    ])


history = np.array(history)


# ============================
# PLOT RESULTS
# ============================

plt.plot(history[:,0], label="Glc_ext")
plt.plot(history[:,1], label="Glc")
plt.plot(history[:,2], label="Glc6P")
plt.plot(history[:,3], label="Fru6P")
plt.plot(history[:,4], label="Fru16P2")
plt.plot(history[:,5], label="Pyruvate")
plt.plot(history[:,6], label="AcCoA_Glc")
plt.plot(history[:,7], label="Cit")
plt.legend()
plt.ylim(-0.01,0.3)
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",   history[-1, 0])
print("Final Glc:",       history[-1, 1])
print("Final Glc6P:",     history[-1, 2])
print("Final Fru6P:",     history[-1, 3])
print("Final Fru16P2:",   history[-1, 4])
print("Final Pyruvate:",  history[-1, 5])
print("Final AcCoA_Glc:", history[-1, 6])
print("Final Cit:",       history[-1, 7])
# Out:
# Final Glc_ext: 7.917909878923136
# Final Glc: 0.20940451816133981
# Final Glc6P: 0.11089847159116203
# Final Fru6P: 0.05432881021074321
# Final Fru16P2: 0.06009565594223672
# Final Pyruvate: 0.07683333888094229
# Final AcCoA_Glc: 0.23310229739431781
# Final Cit: 0.1494171119057295

# %%
# ----------------------------
# Shared settings
# ----------------------------
Glc_in   = 2.0
ATP_draw = 1.0
dt       = 0.01
steps    = 500

def run_case(Cit0):
    Glc_ext    = 0.0
    Glc        = 0.0
    Glc6P      = 0.0
    Fru6P      = 0.0
    Fru16P2    = 0.0
    Pyruvate   = 0.0
    AcCoA_Glc  = 0.0
    AcCoA_Fat  = 0.0
    Cit        = Cit0

    Fru16P2_hist = []
    Pyr_hist     = []
    Cit_hist     = []

    for _ in range(steps):
        Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
        Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
        Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
        Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
        Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
        Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
        AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)
        Cit       += dt * kinetics.dCit_dt(Cit, AcCoA_Glc, AcCoA_Fat, Glc)

        Fru16P2_hist.append(Fru16P2)
        Pyr_hist.append(Pyruvate)
        Cit_hist.append(Cit)

    return np.array(Fru16P2_hist), np.array(Pyr_hist), np.array(Cit_hist)

# ----------------------------
# Run both cases
# ----------------------------
F16_A, Pyr_A, Cit_A = run_case(Cit0=0.0)
F16_B, Pyr_B, Cit_B = run_case(Cit0=5.0)

t = np.arange(steps) * dt

# ----------------------------
# Plot Fru16P2
# ----------------------------
plt.figure(figsize=(8,4))
plt.plot(t, F16_A, label="Fru16P2 (Cit0=0.0)")
plt.plot(t, F16_B, label="Fru16P2 (Cit0=5.0)")
plt.xlabel("time")
plt.ylabel("Fru16P2")
plt.legend()
plt.title("PFK output under low vs high citrate")
plt.show()

# ----------------------------
# Plot Pyruvate
# ----------------------------
plt.figure(figsize=(8,4))
plt.plot(t, Pyr_A, label="Pyruvate (Cit0=0.0)")
plt.plot(t, Pyr_B, label="Pyruvate (Cit0=0.5)")
plt.xlabel("time")
plt.ylabel("Pyruvate")
plt.legend()
plt.title("Pyruvate under low vs high citrate")
plt.show()

# Optional: final values
print("Final Fru16P2 (Cit0=0.0):", F16_A[-1])
print("Final Fru16P2 (Cit0=5.0):", F16_B[-1])
print("Final Pyruvate (Cit0=0.0):", Pyr_A[-1])
print("Final Pyruvate (Cit0=5.0):", Pyr_B[-1])
print("Final Cit (Cit0=0.0):", Cit_A[-1])
print("Final Cit (Cit0=5.0):", Cit_B[-1])
# Out:
# Final Fru16P2 (Cit0=0.0): 0.06009565594223672
# Final Fru16P2 (Cit0=5.0): 0.04987805342362794
# Final Pyruvate (Cit0=0.0): 0.07683333888094229
# Final Pyruvate (Cit0=5.0): 0.06133188480845263
# Final Cit (Cit0=0.0): 0.1494171119057295
# Final Cit (Cit0=5.0): 4.988524020309404

# %% [markdown]
# ### Fat path ODE validation

# %%
# --- CD36 / LCFA_ext verification test ---

LCFA_ext = 0.0   # mM, initial extracellular LCFA
LCFA_in  = 0.2   # mM/min, supply rate

dt    = 0.01     # min
steps = 500

lcfa_ext_history = []

for _ in range(steps):
    LCFA_ext += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)
    lcfa_ext_history.append(LCFA_ext)

lcfa_ext_history = np.array(lcfa_ext_history)

plt.figure(figsize=(6,4))
plt.plot(lcfa_ext_history, label="LCFA_ext")
plt.xlabel("step")
plt.ylabel("LCFA_ext (mM)")
plt.legend()
plt.show()

print("Final LCFA_ext:", LCFA_ext)
# Out:
# Final LCFA_ext: 0.024999999999999915

# %%
# --- LCFA-CoA_cyto verification test ---

# initial conditions
LCFA_ext      = 0.0     # mM, extracellular LCFA
LCFA_in       = 0.2     # mM/min, supply rate
LCFA_CoA_cyto = 0.0     # mM
Mal           = 0.0     # mM
Glc           = 0.0     # mM

dt    = 0.01
steps = 500

history = []

for _ in range(steps):
    # LCFA_ext (CD36 uptake)
    LCFA_ext += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)

    # LCFA-CoA_cyto (CD36 + FAS - CPT1 - TAG)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )

    # append all states
    history.append([
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    ])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="LCFA_ext")
plt.plot(history[:,1], label="LCFA-CoA_cyto")
plt.legend()
plt.show()

# --- final values ---
print("Final LCFA_ext:      ", history[-1,0])
print("Final LCFA-CoA_cyto: ", history[-1,1])
# Out:
# Final LCFA_ext:       0.024999999999999915
# Final LCFA-CoA_cyto:  0.024999999999997136

# %%
# --- LCFA_ext + LCFA-CoA_cyto + LCFA-CoA_mito verification ---

# initial conditions
LCFA_ext       = 0.0
LCFA_in        = 0.2
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
Mal            = 0.0
Glc            = 0.0   # keep 0 for now, like your test

dt    = 0.01
steps = 500

history = []

for _ in range(steps):
    # LCFA_ext (CD36 uptake)
    LCFA_ext += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)

    # LCFA-CoA_cyto (CD36 + FAS - CPT1 - TAG)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )

    # LCFA-CoA_mito (CPT1 - beta-ox)
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )

    history.append([
        LCFA_ext,
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal,
        Glc
    ])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="LCFA_ext")
plt.plot(history[:,1], label="LCFA-CoA_cyto")
plt.plot(history[:,2], label="LCFA-CoA_mito")
plt.legend()
plt.show()

# --- final values ---
print("Final LCFA_ext:       ", history[-1,0])
print("Final LCFA-CoA_cyto:  ", history[-1,1])
print("Final LCFA-CoA_mito:  ", history[-1,2])
# Out:
# Final LCFA_ext:        0.024999999999999915
# Final LCFA-CoA_cyto:   0.024999999999997136
# Final LCFA-CoA_mito:   0.003571428571428198

# %%
# --- LCFA_ext + LCFA-CoA_cyto + LCFA-CoA_mito + AcCoA_Fat verification ---

# initial conditions
LCFA_ext       = 0.0
LCFA_in        = 0.2
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0
Mal            = 0.0
Glc            = 0.0
ATP_draw       = 1.0

dt    = 0.01
steps = 500

history = []

for _ in range(steps):
    # LCFA_ext (CD36 uptake)
    LCFA_ext += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)

    # LCFA-CoA_cyto (CD36 + FAS - CPT1 - TAG)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )

    # LCFA-CoA_mito (CPT1 - beta-ox)
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )

    # AcCoA_Fat (beta-ox - ATP_draw_eff)
    AcCoA_Fat += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # store all states
    history.append([
        LCFA_ext,
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    ])

history = np.array(history)

# --- plot ---
plt.plot(history[:,0], label="LCFA_ext")
plt.plot(history[:,1], label="LCFA-CoA_cyto")
plt.plot(history[:,2], label="LCFA-CoA_mito")
plt.plot(history[:,3], label="AcCoA_Fat")
plt.legend()
plt.show()

# --- final values ---
print("Final LCFA_ext:       ", history[-1,0])
print("Final LCFA-CoA_cyto:  ", history[-1,1])
print("Final LCFA-CoA_mito:  ", history[-1,2])
print("Final AcCoA_Fat:      ", history[-1,3])
print("Final ATP_draw:       ", history[-1,4])
# Out:
# Final LCFA_ext:        0.024999999999999915
# Final LCFA-CoA_cyto:   0.024999999999997136
# Final LCFA-CoA_mito:   0.003571428571428198
# Final AcCoA_Fat:       0.12476594852260708
# Final ATP_draw:        1.0

# %%
# ============================
# INITIAL CONDITIONS (fat only)
# ============================

LCFA_ext       = 0.0
LCFA_in        = 0.2
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0
Cit            = 0.0
Mal            = 0.0

ATP_draw       = 1.0   # shared sink
Glc            = 0.0   # fat-only test → no glucose contribution

dt    = 0.01
steps = 500

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for _ in range(steps):

    # --- CD36 uptake ---
    LCFA_ext += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)

    # --- cytosolic LCFA-CoA ---
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )

    # --- mitochondrial LCFA-CoA ---
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )

    # --- AcCoA from beta-oxidation ---
    AcCoA_Fat += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate from AcCoA_Fat only ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glu=0.0,   # fat-only test
        AcCoA_Fat=AcCoA_Fat,
        Glc=Glc
    )

    # --- malonyl from citrate ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        LCFA_ext,
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        AcCoA_Fat,
        Cit,
        Mal
    ])

history = np.array(history)

# ============================
# PLOT RESULTS
# ============================

plt.plot(history[:,0], label="LCFA_ext")
plt.plot(history[:,1], label="LCFA-CoA_cyto")
plt.plot(history[:,2], label="LCFA-CoA_mito")
plt.plot(history[:,3], label="AcCoA_Fat")
plt.plot(history[:,4], label="Cit")
plt.plot(history[:,5], label="Mal")
plt.legend()
plt.show()

# ============================
# FINAL VALUES
# ============================

print("Final LCFA_ext:",      history[-1,0])
print("Final LCFA-CoA_cyto:", history[-1,1])
print("Final LCFA-CoA_mito:", history[-1,2])
print("Final AcCoA_Fat:",     history[-1,3])
print("Final Cit:",           history[-1,4])
print("Final Mal:",           history[-1,5])
# Out:
# Final LCFA_ext: 0.024999999999999915
# Final LCFA-CoA_cyto: 0.024999999999997136
# Final LCFA-CoA_mito: 0.003571428571428198
# Final AcCoA_Fat: 0.12476594852260708
# Final Cit: 0.10163165901054519
# Final Mal: 0.0

# %% [markdown]
# ### Full integration!

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

Glc_in    = 2.0
LCFA_in   = 0.2
ATP_draw  = 1.0

# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 1000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for _ in range(steps):

    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 1.0)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 1.0)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 14.478343695236552
# Final Glc: 0.2888763133429198
# Final Glc6P: 0.15265648008825045
# Final Fru6P: 0.1004061935622485
# Final Fru16P2: 0.0789231962580512
# Final Pyruvate: 0.11216811507279192
# Final AcCoA_Glc: 0.37139081809357427
# Final LCFA_ext: 0.024999999999999974
# Final LCFA-CoA_cyto: 0.030161474573363312
# Final LCFA-CoA_mito: 0.004088080896922127
# Final AcCoA_Fat: 0.14455347915817773
# Final Cit: 0.6931620580414025
# Final Mal: 0.21870416030142525

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

Glc_in    = 0.1
LCFA_in   = 0.2
ATP_draw  = 0.1

# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 10000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for _ in range(steps):

    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 2.0)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 2.0)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 0.5555555098519879
# Final Glc: 0.026315787329837477
# Final Glc6P: 0.01494616338222655
# Final Fru6P: 1.8009236843720389
# Final Fru16P2: 0.003613222268326274
# Final Pyruvate: 0.004064453164699451
# Final AcCoA_Glc: 0.1979712366718814
# Final LCFA_ext: 0.024999999999999974
# Final LCFA-CoA_cyto: 0.026865719214859796
# Final LCFA-CoA_mito: 0.0036350313088168917
# Final AcCoA_Fat: 11.450020449961173
# Final Cit: 132.3314140410524
# Final Mal: 0.41536974308321983

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

# time-dependent glucose input
def Glc_in_func(t):
    if t < 300:
        return 0.1 + (2.0 - 0.1) * (t / 300)   # linear rise
    elif t < 600:
        return 2.0 - (2.0 - 0.1) * ((t - 300) / 300)  # linear fall
    else:
        return 0.1

# time-dependent fat input (constant here)
def Fat_in_func(t):
    return 0.21


ATP_draw = 0.0


# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 20000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for step in range(steps):

    t = dt * step

    Glc_in_t = Glc_in_func(t)
    LCFA_in_t = Fat_in_func(t)
    
    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in_t)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in_t)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

# ============================
# INPUT FIGURE (1x2)
# ============================

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

t_vals = np.arange(steps) * dt
Glc_in_vals = [Glc_in_func(t) for t in t_vals]
Fat_in_vals = [Fat_in_func(t) for t in t_vals]

# --- Left: Glucose input ---
axes[0].plot(t_vals, Glc_in_vals, label="Glc_in(t)", color="tab:blue")
axes[0].set_title("Glucose Input")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Input Rate")
axes[0].legend(loc="upper left")

# --- Right: Fat input ---
axes[1].plot(t_vals, Fat_in_vals, label="Fat_in(t)", color="tab:orange")
axes[1].set_title("Fat Input")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Input Rate")
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 5.0)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 5.0)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 36.117834474830744
# Final Glc: 0.3906760163395749
# Final Glc6P: 0.2037654980819771
# Final Fru6P: 70.99023881210627
# Final Fru16P2: 0.0004750023119473389
# Final Pyruvate: 0.0007410186642447525
# Final AcCoA_Glc: 3.5124184802074914
# Final LCFA_ext: 0.026582278481012633
# Final LCFA-CoA_cyto: 0.060227902793515385
# Final LCFA-CoA_mito: 0.004721292386491428
# Final AcCoA_Fat: 47.359414056964376
# Final Cit: 1120.4134692988205
# Final Mal: 4.522577547071922

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

# amplitude and baseline can be tuned
def Glc_in_func(t):
    baseline = 0.2
    amplitude = 0.1
    period = 1000
    return baseline + amplitude * np.sin(t / period)

def Fat_in_func(t):
    baseline = 0.21
    amplitude = 0.05
    period = 1000
    phase = np.pi / 2   # fat peaks later than glucose
    #return baseline + amplitude * np.sin(t / period + phase)
    return baseline

ATP_draw = 0.0


# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 20000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for step in range(steps):

    t = dt * step

    Glc_in_t = Glc_in_func(t)
    LCFA_in_t = Fat_in_func(t)
    
    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in_t)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in_t)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

# ============================
# INPUT FIGURE (1x2)
# ============================

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

t_vals = np.arange(steps)
Glc_in_vals = [Glc_in_func(t) for t in t_vals]
Fat_in_vals = [Fat_in_func(t) for t in t_vals]

# --- Left: Glucose input ---
axes[0].plot(t_vals, Glc_in_vals, label="Glc_in(t)", color="tab:blue")
axes[0].set_title("Glucose Input")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Input Rate")
axes[0].legend(loc="upper left")

# --- Right: Fat input ---
axes[1].plot(t_vals, Fat_in_vals, label="Fat_in(t)", color="tab:orange")
axes[1].set_title("Fat Input")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Input Rate")
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()



fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 3.0)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 3.0)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 1.40257160011736
# Final Glc: 0.061492995913348676
# Final Glc6P: 0.03463787569172447
# Final Fru6P: 22.782025018371737
# Final Fru16P2: 0.00048438029208267225
# Final Pyruvate: 0.0007587382420456997
# Final AcCoA_Glc: 3.6082977174621638
# Final LCFA_ext: 0.026582278481012633
# Final LCFA-CoA_cyto: 0.0335034299071461
# Final LCFA-CoA_mito: 0.003935621019452586
# Final AcCoA_Fat: 43.3927571221038
# Final Cit: 1092.1463996202633
# Final Mal: 1.4641136175185052

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

# amplitude and baseline can be tuned
def Glc_in_func(t):
    baseline = 0.05
    amplitude = 0.01
    period = 1000
    #return baseline + amplitude * np.sin(t / period)
    return baseline

def Fat_in_func(t):
    baseline = 0.21
    amplitude = 0.05
    period = 1000
    phase = np.pi / 2   # fat peaks later than glucose
    return baseline + amplitude * np.sin(t / period + phase)
    #return baseline


ATP_draw = 0.0

# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 20000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for step in range(steps):

    t = dt * step

    Glc_in_t = Glc_in_func(t)
    LCFA_in_t = Fat_in_func(t)
    
    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in_t)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in_t)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

# ============================
# INPUT FIGURE (1x2)
# ============================

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

t_vals = np.arange(steps)
Glc_in_vals = [Glc_in_func(t) for t in t_vals]
Fat_in_vals = [Fat_in_func(t) for t in t_vals]

# --- Left: Glucose input ---
axes[0].plot(t_vals, Glc_in_vals, label="Glc_in(t)", color="tab:blue")
axes[0].set_title("Glucose Input")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Input Rate")
axes[0].legend(loc="upper left")

# --- Right: Fat input ---
axes[1].plot(t_vals, Fat_in_vals, label="Fat_in(t)", color="tab:orange")
axes[1].set_title("Fat Input")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Input Rate")
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()



fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 0.5)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 0.5)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 0.2631578947368267
# Final Glc: 0.01282051282051207
# Final Glc6P: 0.007304293678485849
# Final Fru6P: 4.0493169021482585
# Final Fru16P2: 0.00044012103544360814
# Final Pyruvate: 0.0006311088901496724
# Final AcCoA_Glc: 2.0528199758517225
# Final LCFA_ext: 0.03495370200173228
# Final LCFA-CoA_cyto: 0.03727387613282025
# Final LCFA-CoA_mito: 0.004754746057113721
# Final AcCoA_Fat: 52.07689839910642
# Final Cit: 1155.471969243188
# Final Mal: 0.422951655845282

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

# amplitude and baseline can be tuned
def Glc_in_func(t):
    baseline = 0.05
    amplitude = 0.01
    period = 1000
    #return baseline + amplitude * np.sin(t / period)
    return baseline

def Fat_in_func(t):
    baseline = 0.21
    amplitude = 0.05
    period = 1000
    phase = np.pi / 2   # fat peaks later than glucose
    return baseline + amplitude * np.sin(t / period + phase)
    #return baseline


ATP_draw = 1.0

# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 20000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for step in range(steps):

    t = dt * step

    Glc_in_t = Glc_in_func(t)
    LCFA_in_t = Fat_in_func(t)
    
    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in_t)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in_t)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

# ============================
# INPUT FIGURE (1x2)
# ============================

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

t_vals = np.arange(steps)
Glc_in_vals = [Glc_in_func(t) for t in t_vals]
Fat_in_vals = [Fat_in_func(t) for t in t_vals]

# --- Left: Glucose input ---
axes[0].plot(t_vals, Glc_in_vals, label="Glc_in(t)", color="tab:blue")
axes[0].set_title("Glucose Input")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Input Rate")
axes[0].legend(loc="upper left")

# --- Right: Fat input ---
axes[1].plot(t_vals, Fat_in_vals, label="Fat_in(t)", color="tab:orange")
axes[1].set_title("Fat Input")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Input Rate")
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()



fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 0.5)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 0.5)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 0.2631578947368267
# Final Glc: 0.01282051282051207
# Final Glc6P: 0.007304293678485849
# Final Fru6P: 0.01876185902934399
# Final Fru16P2: 0.004800013196805738
# Final Pyruvate: 0.0051562189638553685
# Final AcCoA_Glc: 0.01730208629911796
# Final LCFA_ext: 0.03495370200173228
# Final LCFA-CoA_cyto: 0.0371633136259612
# Final LCFA-CoA_mito: 0.004754348270738232
# Final AcCoA_Fat: 0.17613153275428248
# Final Cit: 7.644027897000837
# Final Mal: 0.4012058700207975

# %%
# ============================
# INITIAL CONDITIONS
# ============================

# --- glucose side ---
Glc_ext    = 0.0
Glc        = 0.0
Glc6P      = 0.0
Fru6P      = 0.0
Fru16P2    = 0.0
Pyruvate   = 0.0
AcCoA_Glc  = 0.0

# --- fat side ---
LCFA_ext       = 0.0
LCFA_CoA_cyto  = 0.0
LCFA_CoA_mito  = 0.0
AcCoA_Fat      = 0.0

# --- regulators ---
Cit = 0.0
Mal = 0.0

# ============================
# USER INPUTS
# ============================

# amplitude and baseline can be tuned
def Glc_in_func(t):
    baseline = 0.5
    amplitude = 0.01
    period = 1000
    #return baseline + amplitude * np.sin(t / period)
    return baseline

def Fat_in_func(t):
    baseline = 0.21
    amplitude = 0.05
    period = 1000
    phase = np.pi / 2   # fat peaks later than glucose
    #return baseline + amplitude * np.sin(t / period + phase)
    #return baseline
    return 0.0


ATP_draw = 1.0

# ============================
# INTEGRATION SETTINGS
# ============================

dt    = 0.01
steps = 20000

history = []

# ============================
# MAIN INTEGRATION LOOP
# ============================

for step in range(steps):

    t = dt * step

    Glc_in_t = Glc_in_func(t)
    LCFA_in_t = Fat_in_func(t)
    
    # --- glucose chain ---
    Glc_ext   += dt * kinetics.dGlc_ext_dt(Glc_ext, Glc_in_t)
    Glc       += dt * kinetics.dGlc_dt(Glc, Glc_ext)
    Glc6P     += dt * kinetics.dGlc6P_dt(Glc6P, Glc)
    Fru6P     += dt * kinetics.dFru6P_dt(Fru6P, Glc6P, Cit)
    Fru16P2   += dt * kinetics.dFru16P2_dt(Fru16P2, Fru6P, Cit)
    Pyruvate  += dt * kinetics.dPyruvate_dt(Pyruvate, Fru16P2, AcCoA_Glc)
    AcCoA_Glc += dt * kinetics.dAcetylCoA_Glc_dt(AcCoA_Glc, Pyruvate, ATP_draw)

    # --- fat chain ---
    LCFA_ext      += dt * kinetics.dLCFA_ext_dt(LCFA_ext, LCFA_in_t)
    LCFA_CoA_cyto += dt * kinetics.dLCFA_CoA_cyto_dt(
        LCFA_ext,
        LCFA_CoA_cyto,
        Mal,
        Glc
    )
    LCFA_CoA_mito += dt * kinetics.dLCFA_CoA_mito_dt(
        LCFA_CoA_cyto,
        LCFA_CoA_mito,
        Mal
    )
    AcCoA_Fat     += dt * kinetics.dAcCoA_Fat_dt(
        LCFA_CoA_mito,
        AcCoA_Fat,
        ATP_draw
    )

    # --- citrate (from both AcCoA pools) ---
    Cit += dt * kinetics.dCit_dt(
        Cit,
        AcCoA_Glc,
        AcCoA_Fat,
        Glc
    )

    # --- malonyl (ACC activation by citrate + glucose) ---
    Mal += dt * kinetics.dMal_dt(
        Cit,
        Mal,
        Glc
    )

    history.append([
        Glc_ext, Glc, Glc6P, Fru6P, Fru16P2,
        Pyruvate, AcCoA_Glc,
        LCFA_ext, LCFA_CoA_cyto, LCFA_CoA_mito, AcCoA_Fat,
        Cit, Mal
    ])

history = np.array(history)

##### PLOTTING #####

# ============================
# INPUT FIGURE (1x2)
# ============================

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

t_vals = np.arange(steps)
Glc_in_vals = [Glc_in_func(t) for t in t_vals]
Fat_in_vals = [Fat_in_func(t) for t in t_vals]

# --- Left: Glucose input ---
axes[0].plot(t_vals, Glc_in_vals, label="Glc_in(t)", color="tab:blue")
axes[0].set_title("Glucose Input")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Input Rate")
axes[0].legend(loc="upper left")

# --- Right: Fat input ---
axes[1].plot(t_vals, Fat_in_vals, label="Fat_in(t)", color="tab:orange")
axes[1].set_title("Fat Input")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Input Rate")
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()



fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ============================
# LEFT PANEL — Glucose Pathway
# ============================

axes[0].plot(history[:,0], label="Glc_ext")
axes[0].plot(history[:,1], label="Glc")
axes[0].plot(history[:,2], label="Glc6P")
axes[0].plot(history[:,3], label="Fru6P")
axes[0].plot(history[:,4], label="Fru16P2")
axes[0].plot(history[:,5], label="Pyruvate")
axes[0].plot(history[:,6], label="AcCoA_Glc")
axes[0].plot(history[:,11], label="Cit")  # shared regulator

axes[0].set_title("Glucose Pathway")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Concentration (mM)")
axes[0].set_ylim(-0.01, 0.5)
axes[0].legend(loc="upper left")


# ============================
# RIGHT PANEL — Fat Pathway
# ============================

axes[1].plot(history[:,7],  label="LCFA_ext")
axes[1].plot(history[:,8],  label="LCFA-CoA_cyto")
axes[1].plot(history[:,9],  label="LCFA-CoA_mito")
axes[1].plot(history[:,10], label="AcCoA_Fat")
axes[1].plot(history[:,11], label="Cit")  # shared regulator
axes[1].plot(history[:,12], label="Mal")

axes[1].set_title("Fat Pathway")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Concentration (mM)")
axes[1].set_ylim(-0.01, 0.5)
axes[1].legend(loc="upper left")

plt.tight_layout()
plt.show()


# ============================
# FINAL VALUES
# ============================

print("Final Glc_ext:",      history[-1,0])
print("Final Glc:",          history[-1,1])
print("Final Glc6P:",        history[-1,2])
print("Final Fru6P:",        history[-1,3])
print("Final Fru16P2:",      history[-1,4])
print("Final Pyruvate:",     history[-1,5])
print("Final AcCoA_Glc:",    history[-1,6])

print("Final LCFA_ext:",      history[-1,7])
print("Final LCFA-CoA_cyto:", history[-1,8])
print("Final LCFA-CoA_mito:", history[-1,9])
print("Final AcCoA_Fat:",     history[-1,10])

print("Final Cit:",           history[-1,11])
print("Final Mal:",           history[-1,12])
# Out:
# Final Glc_ext: 4.999862700746951
# Final Glc: 0.16666354775981618
# Final Glc6P: 0.09161418125310748
# Final Fru6P: 1.5684554455834412
# Final Fru16P2: 0.048035515415735516
# Final Pyruvate: 0.06016271547608093
# Final AcCoA_Glc: 0.21117430185941688
# Final LCFA_ext: 0.0
# Final LCFA-CoA_cyto: 0.004173770322484577
# Final LCFA-CoA_mito: 0.0005093566713893526
# Final AcCoA_Fat: 0.015597557346021636
# Final Cit: 9.032749414848599
# Final Mal: 3.243532355264094
