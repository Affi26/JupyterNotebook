# %%
#pip install opencv-python numpy scikit-learn matplotlib pillow

# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from PIL import Image

def segment_image_kmeans(image_path, output_path='segmented_output.png', k):
    """
    Segment an image using K-means clustering.
    
    Parameters:
        image_path (str): Path to the input image.
        output_path (str): Path to save the segmented image.
        k (int): Number of clusters (colors) to segment into. Default is 3.
        
    Returns:
        None. Saves the segmented image to output_path.
    """
    # Load image and convert to RGB (OpenCV loads in BGR)
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    original_shape = image.shape
    
    # Reshape image data to 2D array of pixels
    pixel_data = image.reshape((-1, 3))
    pixel_data = np.float32(pixel_data)
    
    # Apply K-means clustering
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(pixel_data)
    centers = np.uint8(kmeans.cluster_centers_)
    
    # Replace pixels with their cluster centers
    segmented_data = centers[labels.flatten()]
    segmented_image = segmented_data.reshape(original_shape)
    
    # Save segmented image
    segmented_image_pil = Image.fromarray(segmented_image)
    segmented_image_pil.save(output_path)
    print(f"Segmented image saved as {output_path}")

# %%
# example use:
# segment_image_kmeans('your_image.jpg', 'output_segmented.png', k=2)

# %%
segment_image_kmeans('brickwall.jpg', 'output_segmented.png', k=3)
# Out:
# Segmented image saved as output_segmented.png
